# %% [markdown]
# <a href="https://colab.research.google.com/github/vicschweiger/data_pandascollab/blob/main/gapminder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/gapminder_full.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"country":"Pais", "year":"Ano", "population":"População", "continent":"Continente", "life_exp":"Expectativa de Vida", "gdp_cap":"PIB"}, inplace=True)

# %%
# Total de linhas e colunas
df.shape
# Out:
# (1704, 6)

# %%
# Tipos de dados
df.dtypes
# Out:
# country        object
# year            int64
# population      int64
# continent      object
# life_exp      float64
# gdp_cap       float64
# dtype: object

# %%
import matplotlib.pyplot as plt
df.groupby('Continente')['PIB'].mean().plot.barh()
plt.xlabel("PIB");
plt.ylabel("Continente");
plt.title("PIB por Continente");
